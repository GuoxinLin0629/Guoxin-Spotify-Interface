# %%
import spotipy
import json
import webbrowser
import urllib.request
import spotipy.util as util

# %%
with open('weather_key.txt', 'r') as weather_file:
    weather_key = weather_file.read()
print (weather_key)
# Out:
# 888787a55e3844e9aa1142702242910

# %%
city = "Mumbai"

# %%
# copy and paste the url into your browser to see what data you are getting back
request = urllib.request.Request(f"http://api.weatherapi.com/v1/current.json?key={weather_key}&q=London&aqi=no")
response = urllib.request.urlopen(request)

# %%
print(response)
# Out:
# <http.client.HTTPResponse object at 0x0000014ECD6F12A0>

# %%
weather_json = json.loads(response.read())

# %%
print(weather)
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.5171, 'lon': -0.1062, 'tz_id': 'Europe/London', 'localtime_epoch': 1730215788, 'localtime': '2024-10-29 15:29'}, 'current': {'last_updated_epoch': 1730214900, 'last_updated': '2024-10-29 15:15', 'temp_c': 15.1, 'temp_f': 59.2, 'is_day': 1, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png', 'code': 1009}, 'wind_mph': 3.1, 'wind_kph': 5.0, 'wind_degree': 259, 'wind_dir': 'W', 'pressure_mb': 1024.0, 'pressure_in': 30.24, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 82, 'cloud': 50, 'feelslike_c': 15.1, 'feelslike_f': 59.2, 'windchill_c': 15.1, 'windchill_f': 59.1, 'heatindex_c': 14.7, 'heatindex_f': 58.4, 'dewpoint_c': 10.0, 'dewpoint_f': 50.0, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.5, 'gust_mph': 4.9, 'gust_kph': 8.0}}

# %%
forecast = weather["current"]["condition"]["text"]
print(forecast)
# Out:
# Overcast

# %%
with open('spotify_keys.json', 'r') as spotify_file:
    tokens = json.load (spotify_file)

# %%
client_id = tokens["client_id"]
client_secret = tokens["client_secret"]
redirectURI = tokens["redirect"]
username = tokens["username"]

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)
# Out:
# Enter the URL you were redirected to:  https://www.google.com/?code=AQBuhlE1JEKUriikTE8JAmgeEJqt1ozcTAopNA2oH06r_JoISnjM9WNeGzrWWGQ6w9WSJX5e72Booi0vfoKYs6v0tmzn1ktR8FCC7jpuM7L60yhM-DLXUQXLP4APsr2Xm2xqPCy5a_TjdxHdyG-560hzd1CKT1aYq_b14HZMM8QR4uciCMYKAsoK24e_sJB7b2qiT2Pqr6nQEBtTa2myKBRyHQHTAGvq8vk23nNk7iTpK2VCIQEO1WW8Eoobh9BPy_u74o9cQ-AnUGWSIh079M6Izra8KDM

# %%
sp = spotipy.Spotify(auth=token)

# %%
track_results = sp.search(q=forecast, type='track', limit=50)

# %%
tracks = track_results['tracks']['items']

# %%
tracks[0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V5ZYFsSIBwDFJ1Z3MjFic'},
#     'href': 'https://api.spotify.com/v1/artists/4V5ZYFsSIBwDFJ1Z3MjFic',
#     'id': '4V5ZYFsSIBwDFJ1Z3MjFic',
#     'name': 'Wiljan',
#     'type': 'artist',
#     'uri': 'spotify:artist:4V5ZYFsSIBwDFJ1Z3MjFic'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0vUqEgAEleu9zCyQS6mdXy'},
#   'href': 'https://api.spotify.com/v1/albums/0vUqEgAEleu9zCyQS6mdXy',
#   'id': '0vUqEgAEleu9zCyQS6mdXy',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731fb173a4986a1fdc00218733',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021fb173a4986a1fdc00218733',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511fb173a4986a1fdc00218733',
#     'width': 64}],
#   'name': 'Overcast',
#   'release_date': '2017-01-07',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:0vUqEgAEleu9zCyQS6mdXy'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V5ZYFsSIBwDFJ1Z3MjFic'},
#    'href': 'https://api.spotify.com/v1/artists/4V5ZYFsSIBwDFJ1Z3MjFic',
#    'id': '4V5ZYFsSIBwDFJ1Z3MjFic',
#    'name': 'Wiljan',
#    'type': 'artist',
#    'uri': 'spotify:artist:4V5ZYFsSIBwDFJ1Z3MjFic'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 242338,
#  'explicit': False,
#  'external_ids': {'isrc': 'QZDA81832084'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/4JMB7StRYhP9YWrABz5mvv'},
#  'href': 'https://api.spotify.com/v1/tracks/4JMB7StRYhP9YWrABz5mvv',
#  'id': '4JMB7StRYhP9YWrABz5mvv',
#  'is_local': False,
#  'name': 'Overcast',
#  'popularity': 40,
#  'preview_url': 'https://p.scdn.co/mp3-preview/ce48fcd3931b5a614fa0bf3c861b1093d01cf7bc?cid=0ae21d35959544afa955c205a3917ac7',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:4JMB7StRYhP9YWrABz5mvv'}

# %%
track_selection_list = []

for song in tracks:
    track_selection_list.append(song['uri'])

# %%
webbrowser.open(my_palylist{'external_ur
